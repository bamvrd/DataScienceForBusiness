# %%
pip install googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.6.0-py3-none-any.whl size=38554 sha256=b81b0991a1973fe2620daa127b9ed06fa0eb67f1eb3c6656284553a2332ec4e9
#   Stored in directory: /root/.cache/pip/wheels/80/db/c0/6d958585fa97b20e250bf437acf7e6e715b4809c2dd4e55367
# Successfully built googlemaps
# ...

# %%
import pandas as pd
import numpy as np
import re
from scipy import stats
import requests
import json
import glob
import time
import math
import googlemaps

# import os
# os.chdir('/Users/korrakote.s/Desktop/Work/Project/Asset Intelligence')

# %%
# API KEY from Google console
# Ref: https://developers.google.com/maps/documentation/javascript/overview

keys = 'AIzaSyB6UlXRbMi8ItB7cKsgIHfNB0DNfwzeG1U' #mo's api key
# keys = 'AIzaSyDSHh4D-0zhBV87F3i-yzFg3CMyxUTuo5I' #bam's api key

# %% [markdown]
# #get lat long of condos given

# %%
chiangrai_edited = pd.read_csv('/content/chiangrai_with_latlng_rating_edited.csv')
#nakhon = pd.read_csv('/content/gov_price_condo_nakhon_ratchasima.csv');

# %%
chiangrai_edited.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'hs_nm', 'cnd_bld_no', 'cnd_flr_no',
#        'apx_gov_prc', 'details', 'lat', 'lng', 'rating'],
#       dtype='object')

# %%
#drop useless column
chiangrai = chiangrai_edited.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
chiangrai[chiangrai['hs_nm']=='เชียงราย แฮปปี้ ซิตี้ คอนโดมิเนียม']
# Out:
#                                  hs_nm cnd_bld_no  cnd_flr_no apx_gov_prc  \
# 22  เชียงราย แฮปปี้ ซิตี้ คอนโดมิเนียม          -           1      31,400
# 23  เชียงราย แฮปปี้ ซิตี้ คอนโดมิเนียม          -           2      31,800
# 24  เชียงราย แฮปปี้ ซิตี้ คอนโดมิเนียม          -           3      32,400
# 25  เชียงราย แฮปปี้ ซิตี้ คอนโดมิเนียม          -           4      33,000
# 26  เชียงราย แฮปปี้ ซิตี้ คอนโดมิเนียม          -           5      33,700
#
#                                   details        lat        lng  rating
# 22  พื้นที่ห้องชุดพักอาศัย/พื้นที่ระเบียง  19.863547  99.949187     4.3
# 23  พื้นที่ห้องชุดพักอาศัย/พื้นที่ระเบียง  19.863547  99.949187     4.3
# 24  พื้นที่ห้องชุดพักอาศัย/พื้นที่ระเบียง  19.863547  99.949187     4.3
# 25  พื้นที่ห้องชุดพักอาศัย/พื้นที่ระเบียง  19.863547  99.949187     4.3
# 26  พื้นที่ห้องชุดพักอาศัย/พื้นที่ระเบียง  19.863547  99.949187     4.3

# %%
#drop duplicate condo
chiangrai = chiangrai.drop([22,23,24,25,26]).reset_index()

# %%
chiangrai = chiangrai.drop(columns=['index'])

# %%
chiangrai.head(30)
# Out:
#                                 hs_nm cnd_bld_no  cnd_flr_no apx_gov_prc  \
# 0     กัลปพฤกษ์ แกรนด์ พาร์ค เชียงราย          -           2      52,800
# 1     กัลปพฤกษ์ แกรนด์ พาร์ค เชียงราย          -           3      54,400
# 2     กัลปพฤกษ์ แกรนด์ พาร์ค เชียงราย          -           4      55,500
# 3     กัลปพฤกษ์ แกรนด์ พาร์ค เชียงราย          -           5      56,600
# 4   คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          A           2      48,500
# 5   คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          A           3      49,200
# 6   คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          A           4      50,000
# 7   คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          A           5      51,000
# 8   คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          A           6      52,100
# 9   คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          A           7      53,200
# 10  คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          A           8      54,400
# 11  คิวเฮ้าส์ คอนโด พหลโยธิน-เชียงราย          B           2      48,500
# ...

# %%
nakhon.head()

# %%
def fetch_result(results,lat_lon):
    for i in range(len(results['results'])):
        place_id.append(results['results'][i]['place_id'])
        name.append(results['results'][i]['name'])
        latitude.append(results['results'][i]['geometry']['location']['lat'])
        longitude.append(results['results'][i]['geometry']['location']['lng'])
        address.append(results['results'][i]['vicinity'])
        types.append(str(results['results'][i]['types']))
        latlon.append(lat_lon)

# %%
chiangrai["lat"]="a"
chiangrai["lng"]="b"
chiangrai["rating"]=0.0

# %%
for i in range(len(chiangrai['hs_nm'])):
  latlng = get_latlng(chiangrai['hs_nm'][i])
  chiangrai["lat"][i]=latlng.get("lat")
  chiangrai["lng"][i]=latlng.get("lng")
  chiangrai["rating"][i]=latlng.get("rating")

# %%
chiangrai.head(10)

# %%
chiangrai.to_csv('chiangrai.csv')

# %%
nakhon["lat"]="c"
nakhon["lng"]="d"
nakhon["rating"]=0.0

# %%
# 14.1-15.8 || 101.1-103
south = 14.1
west = 101.1
north = 15.8
east = 103

def get_latlng (name):
  url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input="+name+"&inputtype=textquery&locationbias=rectangle%3A"+str(south)+","+str(west)+"|"+str(north)+","+str(east)+"&fields=name%2Crating%2Cgeometry&key="+keys;

  payload={}
  headers = {}

  response = requests.request("GET", url, headers=headers, data=payload)
  latlng = response.json().get("candidates")[0].get("geometry").get("location")
  latlng['rating']=response.json().get("candidates")[0].get("rating")
  return latlng;

for i in range(len(nakhon['hs_nm'])):
  # print(i)
  n_latlng = get_latlng(nakhon['hs_nm'][i])
  nakhon["lat"][i]=n_latlng.get("lat")
  nakhon["lng"][i]=n_latlng.get("lng")
  nakhon["rating"][i]=n_latlng.get("rating")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
nakhon.head(40)

# %%
nakhon.to_csv('nakhon_with_latlng_rating(1).csv')

# %% [markdown]
# # check lat lng of condo in nakhon if it's in the grid of the province
# ## to remove condos that can't be found in the province

# %%
nakhon_manual = pd.read_csv('/content/nakhon_with_latlng_rating.csv');

# %%
# 14.1-15.8 || 101.1-103
pd.unique(nakhon_manual[(nakhon_manual['lat']>15.8)|(nakhon_manual['lat']<14.1)|(nakhon_manual['lng']>103)|(nakhon_manual['lng']<101.1)]['hs_nm'])
# Out:
# array(['แกรนด์ คอนโดมิเนียม', 'คลาสเตอร์เฮ้าส์', 'คลาสเตอร์เฮาส์ 2',
#        'คลาสเตอร์เฮ้าส์ 3', 'คอนโดมิเนียม G', 'คาสเทลโล 2'], dtype=object)

# %%
check_dup = nakhon_manual.groupby(['lat','lng']).size().reset_index()
check_dup[check_dup[0]>1]

# %% [markdown]
# #clean chiangrai
# ##to remove duplicate condos

# %%
ch_unique = pd.read_csv('/content/chiangrai_unique_condo_name.csv');
ch_old = pd.read_csv('/content/chiangrai_with_latlng_rating.csv');

# %%
ch_old['condo']=ch_old['hs_nm']

# %%
ch_old['condo'] = ch_old['condo'].astype(str)
ch_unique['condo'] = ch_unique['condo'].astype(str)

# %%
ch_old.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'hs_nm', 'cnd_bld_no', 'cnd_flr_no',
#        'apx_gov_prc', 'details', 'lat', 'lng', 'rating', 'condo'],
#       dtype='object')

# %%
ch_update = pd.merge(ch_unique, ch_old[['condo','cnd_bld_no','cnd_flr_no','apx_gov_prc','details','rating']], on='condo', how='inner')
ch_update.drop(columns=['Unnamed: 0'], inplace=True)

# %%
len(ch_update)
# Out:
# 119

# %%
len(pd.unique(ch_update['condo']))
# Out:
# 14

# %%
len(ch_unique)
# Out:
# 14

# %%
ch_update.to_csv('/chiangrai_with_latlng_rating_updated.csv')

# %% [markdown]
# #clean nakhon
# ##to remove duplicate condos

# %%
nk_unique = pd.read_csv('/content/nakhon_unique_condo_name.csv');
nk_old = pd.read_csv('/content/nakhon_with_latlng_rating.csv');

# %%
#choose file
data = chiangrai

# %%
#get unique condo's name and its latlng from file
num = len(data['hs_nm'])
condo_name_with_latlng = []
for i in range (num-1):
  if(data['hs_nm'][i] != data['hs_nm'][i+1]):
    info = []
    info.append(data['hs_nm'][i])
    info.append(data['lat'][i])
    info.append(data['lng'][i])
    condo_name_with_latlng.append(info)
info = []
info.append(data['hs_nm'][num-1])
info.append(data['lat'][num-1])
info.append(data['lng'][num-1])
condo_name_with_latlng.append(info)

raw_file_condo_name = pd.DataFrame(condo_name_with_latlng,columns=['condo','lat','lng'])
raw_file_condo_name.to_csv('chiangrai_unique_condo_name.csv')

# %%
nk_unique.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1                                    condo  \
# 0           0             0                             360 คอนโดเทล
# 1           1             1                                 360 พาโน
# 2           2             2                       แกรนด์ เอเวอร์ไนน์
# 3           3             3                       โกลเด้นเบล แมนชั่น
# 4           4             4  เขาใหญ่ แคลิฟอร์เนีย พาร์ค คอนโดมิเนียม
#
#          lat         lng
# 0  14.599583  101.368556
# 1  14.599183  101.370081
# 2  14.976079  102.081063
# 3  14.661438  101.400219
# 4  14.579241  101.400969

# %%
nk_old.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1         hs_nm     cnd_bld_no cnd_flr_no  \
# 0           0             0  360 คอนโดเทล  1(ไม่มีลิฟต์)          1
# 1           1             1  360 คอนโดเทล  1(ไม่มีลิฟต์)          2
# 2           2             2  360 คอนโดเทล  1(ไม่มีลิฟต์)          3
# 3           3             3  360 คอนโดเทล     2(มีลิฟต์)          1
# 4           4             4  360 คอนโดเทล     2(มีลิฟต์)          2
#
#   apx_gov_prc                                details        lat         lng  \
# 0      64,300  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง  14.599583  101.368556
# 1      62,400  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง  14.599583  101.368556
# 2      61,000  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง  14.599583  101.368556
# 3      61,600  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง  14.599583  101.368556
# 4      62,400  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง  14.599583  101.368556
#
#    rating         condo
# 0     4.0  360 คอนโดเทล
# 1     4.0  360 คอนโดเทล
# ...

# %%
nk_old['condo']=nk_old['hs_nm']

# %%
nk_old[['condo','cnd_bld_no','cnd_flr_no','apx_gov_prc','details','rating']].join(nk_unique, on=['condo'], how='inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-2fb584a2c3df> in <module>()
# ----> 1 nk_old[['condo',        'cnd_bld_no', 'cnd_flr_no', 'apx_gov_prc', 'details',   'rating']].join(nk_unique, on=['condo'], how='inner')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
#    9140         else:
#
# ...

# %%
nk_old['condo'] = nk_old['condo'].astype(str)
nk_unique['condo'] = nk_unique['condo'].astype(str)

# %%
nk_update = pd.merge(nk_unique, nk_old[['condo','cnd_bld_no','cnd_flr_no','apx_gov_prc','details','rating']], on='condo', how='inner')
nk_update.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)

# %%
nk_update.tail()
# Out:
#                                 condo        lat         lng cnd_bld_no  \
# 619  แสนดาวเขาใหญ่ คอนโด บ้านเคียงดาว  14.555326  101.310481          1
# 620  แสนดาวเขาใหญ่ คอนโด บ้านเคียงดาว  14.555326  101.310481          1
# 621  แสนดาวเขาใหญ่ คอนโด บ้านเคียงดาว  14.555326  101.310481          1
# 622  แสนดาวเขาใหญ่ คอนโด บ้านเคียงดาว  14.555326  101.310481          1
# 623  แสนดาวเขาใหญ่ คอนโด บ้านเคียงดาว  14.555326  101.310481          1
#
#     cnd_flr_no apx_gov_prc                                details  rating
# 619          3      73,300  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง     4.6
# 620          4      74,700  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง     4.6
# 621          5      76,300  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง     4.6
# 622          6      77,900  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง     4.6
# 623          7      79,700  ห้องชุดพักอาศัยตากอากาศ/พื้นทีระเบียง     4.6

# %%
len(nk_update)
# Out:
# 624

# %%
len(pd.unique(nk_update['condo']))
# Out:
# 82

# %%
len(nk_unique)
# Out:
# 82

# %%
nk_update.to_csv('/nakhon_with_latlng_rating.csv')

# %% [markdown]
# # get POI of each condo in both province

# %%
import pandas as pd

# %%
#ch_file = pd.read_csv('/content/chiangrai_with_latlng_rating.csv');
# nk_file = pd.read_csv('/content/nakhon_with_latlng_rating.csv');

# %%
ch_condo = pd.read_csv('/content/chiangrai_unique_condo_name.csv');
# nk_condo = pd.read_csv('/content/nakhon_unique_condo_name.csv');

# %%
# choosing 17 places and radious
type_param  = [['atm', 300], ['bar', 2000], ['gas_station', 1000], ['convenience_store', 200],
              ['department_store', 800], ['hospital', 1000], ['university', 2000], ['supermarket', 800], ['gym', 1000],
              ['shopping_mall', 800], ['laundry', 300], ['movie_theater', 800], ['park', 500], ['night_club', 2000], 
              ['primary_school', 2000], ['school',2000], ['tourist_attraction', 2000]]

# %%
# choose file
file = ch_condo

# %% [markdown]
# Nearby search result:
# https://developers.google.com/maps/documentation/places/web-service/search-nearby

# %%
def fetch_result(results,lat_lon,apartment_name):
    for i in range(len(results['results'])):
        condo.append(apartment_name)
        latlon.append(lat_lon)
        place_name.append(results['results'][i]['name'])
        place_id.append(results['results'][i]['place_id'])
        latitude.append(results['results'][i]['geometry']['location']['lat'])
        longitude.append(results['results'][i]['geometry']['location']['lng'])
        types.append(str(results['results'][i]['types']))
        price_level.append(results['results'][i].get('price_level'))
        rating.append(results['results'][i].get('rating'))
        num_rating.append(results['results'][i].get('user_ratings_total'))

# %%
def create_result(url):
    payload={}
    headers = {}
    response = requests.request("GET", url, headers=headers, data=payload)
    results = json.loads(response.content)
    return results

# %%
for j in range(len(type_param)):
  condo = []
  latlon =[]

  place_name = []
  place_id = []
  latitude = []
  longitude = []
  types = []
  price_level = []
  rating = []
  num_rating = []

  for i in range(len(file['condo'])):
    lat = file['lat'][i]
    lon = file['lng'][i]
    coordinate = [lat,lon]

    # Get API results
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="+str(lat)+","+str(lon)+"&radius="+str(radius)+"&type="+str(type_param[j])+"&key="+keys
    results = create_result(url)    
    fetch_result(results,coordinate,file['condo'][i])

  # Combine results
  df = {'origin_name': condo, 
        'origin_latlon':latlon,
        'place_name':place_name,
        'place_id':place_id,
        'latitude':latitude,'longitude':longitude,
        'type':types, 
        'price_level':price_level,
        'rating':rating, 
        'total_user_rate':num_rating}
  data = pd.DataFrame(df)
  data.to_csv(str(type_param[j])+'_'+str(radius)+'m.csv')

# %%
condo = []
latlon =[]

place_name = []
place_id = []
latitude = []
longitude = []
types = []
price_level = []
rating = []
num_rating = []

for i in range(len(file['condo'])):
  lat = file['lat'][i]
  lon = file['lng'][i]
  coordinate = [lat,lon]

  # Get API results
  url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="+str(lat)+","+str(lon)+"&radius="+str(radius)+"&type="+type_param[18][0]+"&key="+keys
  results = create_result(url)    
  fetch_result(results,coordinate,file['condo'][i])

# Combine results
df = {'origin_name': condo, 
      'origin_latlon':latlon,
      'place_name':place_name,
      'place_id':place_id,
      'latitude':latitude,'longitude':longitude,
      'type':types, 
      'price_level':price_level,
      'rating':rating, 
      'total_user_rate':num_rating}
data = pd.DataFrame(df)
data.to_csv(type_param[18][0]+'_'+str(1000)+'m.csv')

# %% [markdown]
# #find distance from condo to POI

# %%
# Python 3 program to calculate Distance Between Two Points on Earth
from math import radians, cos, sin, asin, sqrt
def distance(lat1, lat2, lon1, lon2):
    # The math module contains a function named
    # radians which converts from degrees to radians.
    lon1 = radians(float(lon1))
    lon2 = radians(float(lon2))
    lat1 = radians(float(lat1))
    lat2 = radians(float(lat2))
      
    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
 
    c = 2 * asin(sqrt(a))
    
    # Radius of earth in kilometers. Use 3956 for miles
    r = 6371
      
    # calculate the result
    return(c * r)

# %%
#calculate distance

for i in range(len(type_param)): 
  file = pd.read_csv('/content/ch_'+type_param[i][0]+'_'+str(type_param[i][1])+'m.csv')
  file['condo_latlng']=0.0
  for i in range(len(file)):
    latlon = file['origin_latlon'][i].replace("[", "").replace("]", "")
    file['condo_latlng'][i] = latlon.split(',')
    file['condo_latlng'][i][0] = float(file['condo_latlng'][i][0])
    file['condo_latlng'][i][1] = float(file['condo_latlng'][i][1])
  file['distance_to_condo']=0.0
  for row in range(len(file)):
    lat1 = file['condo_latlng'][row][0]
    lon1 = file['condo_latlng'][row][1]
    lat2 = file['latitude'][row]
    lon2 = file['longitude'][row]
    file['distance_to_condo'][row] = distance(lat1, lat2, lon1, lon2)

#turn distance into feature: mean and count

  group_file = file[['origin_name', 'price_level', 'rating', 'distance_to_condo']].groupby(by="origin_name").mean()
  group_file = group_file.join( file[['origin_name', 'total_user_rate']].groupby(by="origin_name").sum(), on=['origin_name']).join( file[['origin_name', 'place_id']].groupby(by="origin_name").count(), on=['origin_name'])
  group_file = group_file.reset_index()
  group_file.columns = ['origin_name', 'poi_price_level', 'poi_avg_rating', 'avg_distance_to_condo (KM)',
        'num_of_rating', 'poi_count']
  group_file.to_csv(type_param[i][0]+'_'+str(1000)+'m.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
def get_distance_nk(file):
  
  file['condo_latlng']=0.0
  for i in range(len(file)):
    latlon = file['origin_latlon'][i].replace("[", "").replace("]", "")
    file['condo_latlng'][i] = latlon.split(',')
    file['condo_latlng'][i][0] = float(file['condo_latlng'][i][0])
    file['condo_latlng'][i][1] = float(file['condo_latlng'][i][1])
  file['distance_to_condo']=0.0
  for row in range(len(file)):
    lat1 = file['condo_latlng'][row][0]
    lon1 = file['condo_latlng'][row][1]
    lat2 = file['latitude'][row]
    lon2 = file['longitude'][row]
    file['distance_to_condo'][row] = distance(lat1, lat2, lon1, lon2)
  return file

# %%
def get_distance_ch(file):
  # file = pd.read_csv('/content/ch_'+type_param[i][0]+'_'+str(type_param[i][1])+'m.csv')
  file['condo_latlng']=0.0
  for i in range(len(file)):
    latlon = file['origin_latlon'][i].replace("[", "").replace("]", "")
    file['condo_latlng'][i] = latlon.split(',')
    file['condo_latlng'][i][0] = float(file['condo_latlng'][i][0])
    file['condo_latlng'][i][1] = float(file['condo_latlng'][i][1])
  file['distance_to_condo']=0.0
  for row in range(len(file)):
    lat1 = file['condo_latlng'][row][0]
    lon1 = file['condo_latlng'][row][1]
    lat2 = file['latitude'][row]
    lon2 = file['longitude'][row]
    file['distance_to_condo'][row] = distance(lat1, lat2, lon1, lon2)
  return file

# %%
#turn distance into feature: mean and count
def count_num(file,i):
  group_file = file[['origin_name', 'price_level', 'rating', 'distance_to_condo']].groupby(by="origin_name").mean()
  group_file = group_file.join( file[['origin_name', 'total_user_rate']].groupby(by="origin_name").sum(), on=['origin_name']).join( file[['origin_name', 'place_id']].groupby(by="origin_name").count(), on=['origin_name'])
  group_file = group_file.reset_index()
  name = type_param[i][0]
  group_file.columns = ['condo', name+'_price_level', name+'_avg_rating', name+'_avg_distance_to_condo (KM)',name+'_num_of_rating', name+'_count']
  return group_file

# %%
for i in range(len(type_param):
  count_num(get_distance(i))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#change column name
i=0
name = type_param[i][0]
group_file.columns = ['origin_name', name+'_price_level', name+'_avg_rating', name+'_avg_distance_to_condo (KM)',name+'_num_of_rating', name+'_count']
group_file
# Out:
#                        origin_name  atm_price_level  atm_avg_rating  \
# 0  กัลปพฤกษ์ แกรนด์ พาร์ค เชียงราย              NaN        5.000000
# 1                      ดีคอนโด ฮาย              NaN        3.516667
# 2                    ทองคำคอนโดเทล              NaN        4.166667
# 3                 เชียงรายคอนโดเทล              NaN        5.000000
# 4         เอสเซ็นท์ วิลล์ เชียงราย              NaN        3.900000
#
#    atm_avg_distance_to_condo (KM)  atm_num_of_rating  atm_count
# 0                        0.238583                5.0          6
# 1                        0.211690               27.0         20
# 2                        0.161540               12.0         20
# 3                        0.245485                1.0          4
# 4                        0.220301               16.0          8

# %% [markdown]
# #Merge POI files with original csv

# %%
nakhon_merge = pd.read_csv('/content/nakhon_with_latlng_rating.csv')
for i in range(len(type_param)): 
  file = pd.read_csv('/content/nk_'+type_param[i][0]+'_'+str(type_param[i][1])+'m.csv')
  file = get_distance_nk(file)
  group_file = file[['origin_name', 'price_level', 'rating', 'distance_to_condo']].groupby(by="origin_name").mean()
  group_file = group_file.join( file[['origin_name', 'total_user_rate']].groupby(by="origin_name").sum(), on=['origin_name']).join( file[['origin_name', 'place_id']].groupby(by="origin_name").count(), on=['origin_name'])
  group_file = group_file.reset_index()
  name = type_param[i][0]
  group_file.columns = ['condo', name+'_price_level', name+'_avg_rating', name+'_avg_distance_to_condo (KM)',name+'_num_of_rating', name+'_count']
  nakhon_merge = nakhon_merge.merge(group_file, how='left',on='condo')
nakhon_merge.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
nakhon_merge.to_csv('nakhon_merge.csv')

# %%
chiangrai_merge = pd.read_csv('/content/chiangrai_with_latlng_rating_updated.csv')
for i in range(len(type_param)): 
  file = pd.read_csv('/content/ch_'+type_param[i][0]+'_'+str(type_param[i][1])+'m.csv')
  file = get_distance_ch(file)
  group_file = file[['origin_name', 'price_level', 'rating', 'distance_to_condo']].groupby(by="origin_name").mean()
  group_file = group_file.join( file[['origin_name', 'total_user_rate']].groupby(by="origin_name").sum(), on=['origin_name']).join( file[['origin_name', 'place_id']].groupby(by="origin_name").count(), on=['origin_name'])
  group_file = group_file.reset_index()
  name = type_param[i][0]
  group_file.columns = ['condo', name+'_price_level', name+'_avg_rating', name+'_avg_distance_to_condo (KM)',name+'_num_of_rating', name+'_count']
  chiangrai_merge = chiangrai_merge.merge(group_file, how='left',on='condo')
chiangrai_merge.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
chiangrai_merge.to_csv('chiangrai_merge.csv')
